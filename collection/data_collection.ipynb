# %% [markdown]
# # Data Collection: Laptop Price Dataset

# %%
# import libraries for collecting data 
import pandas as pd 
import os
from data_ingestor import FileDataIngestor

# %% [markdown]
# ## Data Ingestion

# %%
# Initialise constants for extracting data 
dataset_path = "D:\Projectwork Platform\MEP-Machine-Learning\Laptop_Price_Prediction\dataset"
filename = "ebay_laptop_dataset"
extension = ".csv"

# Ingest the dataset of 
ingestor = FileDataIngestor(filename = filename)
laptop_df = ingestor.ingest(data_path=dataset_path)
laptop_df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\mian_\AppData\Local\Temp\ipykernel_18596\2398638876.py:2: SyntaxWarning: invalid escape sequence '\P'
#   dataset_path = "D:\Projectwork Platform\MEP-Machine-Learning\Laptop_Price_Prediction\dataset"
# 5
#    Brand   Price Currency  Color  \
# 0  other  303.80        $   gray
# 1   dell  400.00        $  black
# 2   dell  175.00        $  black
# 3     hp   85.00        $  black
# 4   dell  101.25        $  other
#
#                                             Features                Condition  \
# 0  Backlit Keyboard,  Built-in Microphone,  Built...                      New
# 1  Backlit Keyboard, Bluetooth, Built-in Micropho...  Very Good - Refurbished
# 2  10/100 LAN Card, Backlit Keyboard, Bluetooth, ...                     Used
# 3  Bluetooth, Built-in Microphone, Built-in Webca...       Good - Refurbished
# ...

# %%
# Extract data from the dataset folder
extracted_files = os.listdir(dataset_path)
csv_files = [file for file in extracted_files if file.endswith(".csv")]
csv_files
# extracte_files
# Out:
# ['ebay_laptop_dataset.csv',
#  'ebay_laptop_data_cleaned.csv',
#  'ebay_laptop_data_phase3.csv',
#  'ebay_laptop_data_recognised.csv',
#  'ebay_laptop_data_unrecognised.csv']

# %% [markdown]
# ## Data Ingestion: Insights

# %% [markdown]
# The dataset folder contains a couple of datasets that have already been processed and refined through the previous coding progress. The ebay laptop dataset is selected for the following procedure of the laptop price prediction. It requires more processing and analysis workload before building a model to predict the price of a laptop based on its properties.
