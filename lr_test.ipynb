# %% [markdown]
# ## Linear Regression: Test

# %%
# Import libraries
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt 

# Import dependencies to build linear model
# from feature_engineering import FeatureEncoder, FeatureScaler
# from data_preparation import DataPreparator
# from collection.data_ingestor import DataIngestor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 import matplotlib.pyplot as plt
#       7 # Import dependencies to build linear model
# ----> 8 from feature_engineering import FeatureEncoder, FeatureScaler
#       9 from data_preparation import DataPreparator
#      10 # from collection.data_ingestor import DataIngestor
#
# ModuleNotFoundError: No module named 'feature_engineering'

# %% [markdown]
# ## Data Loading

# %%
# Load the dataset from phase 3
path = "D:\Projectwork Platform\MEP-Machine-Learning\Laptop_Price_Prediction\dataset"
csv_file = os.path.join(path, "ebay_laptop_data_phase3.csv")
laptop_df = pd.read_csv(csv_file)
laptop_df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\mian_\AppData\Local\Temp\ipykernel_6620\3772760037.py:2: SyntaxWarning: invalid escape sequence '\P'
#   path = "D:\Projectwork Platform\MEP-Machine-Learning\Laptop_Price_Prediction\dataset"
#   Brand   Price  Color    GPU  Processor Speed  Display Width  Display Height  \
# 0  dell  400.00  black  intel              4.2         1920.0          1080.0
# 1  dell  175.00  black  intel              2.4         1920.0          1080.0
# 2    hp   85.00  black  intel              2.4         1366.0           768.0
# 3  dell  101.25  other  other              1.4         1366.0           768.0
# 4  acer   50.00  black  other              1.6         1366.0           768.0
#
#         OS Storage Type  Hard Drive Capacity  SSD Capacity  Screen Size (cm)  \
# 0  windows          ssd              2000.00        205.95              14.0
# ...

# %% [markdown]
# ## Data Parapation

# %%
data_preparator = DataPreparator("ebay_laptop_data_phase3", path=path)
laptop_ds = data_preparator.dataset
laptop_ds.head()
# Out:
#   Brand   Price  Color    GPU  Processor Speed  Display Width  Display Height  \
# 0  dell  400.00  black  intel              4.2         1920.0          1080.0
# 1  dell  175.00  black  intel              2.4         1920.0          1080.0
# 2    hp   85.00  black  intel              2.4         1366.0           768.0
# 3  dell  101.25  other  other              1.4         1366.0           768.0
# 4  acer   50.00  black  other              1.6         1366.0           768.0
#
#         OS Storage Type  Hard Drive Capacity  SSD Capacity  Screen Size (cm)  \
# 0  windows          ssd              2000.00        205.95              14.0
# 1  windows          ssd               500.00        500.00              14.0
# 2   chrome         emmc                16.00        205.95              11.6
# 3  windows          ssd                98.89        256.00              12.5
# 4   chrome          ssd                98.89         16.00              11.6
#
# ...

# %%
(xtrain, ytrain), (xtest, ytest) = data_preparator.data_splitting("Display Width", "Price")
ytest
# Out:
# 1516    680.0
# 281     417.8
# 1378    247.0
# 395     490.0
# 718     131.2
#         ...
# 1386     29.0
# 2103    159.0
# 389      95.4
# 326     180.0
# 483     427.0
# Name: Price, Length: 618, dtype: float64

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## LNN-model

# %%
import tensorflow as tf
